# %% [markdown]
# # COMP 4030/6030 - Assignment 2
# **Due: 09/23/2025**
#
# **Instructions**: Complete all problems in this notebook. Show all work for full credit. You must complete this assignment independently without help from other people or AI. Violation of this policy will result in a zero and referral to the Office of Student Accountability.
#
# ---
#
# **Write your name here**: Ibra Niang

# %% [markdown]
# ## Part 1: Running Time Analysis (40 points)
#
# For each function below, determine the running time equation T(n). Use constants (a, b, c, etc.) to represent different code blocks. Show your step counting clearly.

# %% [markdown]
# ### Problem 1.1 (5 points)
# Analyze the following function and determine T(n):
#
# ```python
# def compute_sum(n):
#     result = 0                  # a step
#     counter = 0                 # b step
#     for i in range(n):          # n steps
#         result += i * 2         # c step
#         counter += 1            # d step
#     final = result / counter    # e step
#     return final                # i step
#
# ```
#
# **Your answer:**
# ```
# Line by line analysis:
# 6 -> takes a step
# 7 -> takes b step
# 8 -> takes n steps
# 9 -> takes c step
# 10 -> takes d step
# 11 -> takes e step
# 12 -> takes i step
# where x = a + b + e + i
#
#
# T(n) = x + (c+d)*n
# ```

# %% [markdown]
# ### Problem 1.2 (5 points)
# Count the steps and find T(n):
#
# ```python
# def process_array(L):    # n = len(L)
#     max_val = L[0]             # a step
#     min_val = L[0]             # b step
#
#     for item in L:             # n steps
#         if item > max_val:     # c step
#             max_val = item     # d step
#         if item < min_val:     # e step
#             min_val = item     # f step
#
#     return max_val - min_val   # i step
# ```
#
# **Your answer:**
# ```
# Line by line analysis:
#
# 6 -> a step
# 7 -> b step
# 9 -> n steps
# 10 -> c step
# 11 -> d step
# 12 -> e step
# 13 -> f step
# 15 -> i step
#
# where x = a + b + i
#
# T(n) = x + (c + d + e + f)*n
# ```

# %% [markdown]
# ### Problem 1.3 (8 points)
# Analyze this nested loop structure:
#
# ```python
# def matrix_operation(L):    # n = len(L)
#     result = 0                     # a step
#     for i in range(len(L)):        # n steps
#         for j in range(len(L)):    # n steps
#             result += L[i] * L[j]  # b step
#             result = result % 1000 # c step
#     return result                  # i step
# ```
#
# **Your answer:**
# ```
# Line by line analysis:
# 6 -> a step
# 7 -> n steps
# 8 -> n steps
# 9 -> b step
# 10 -> c step
# 11 -> i step
#
#
# T(n) = a + (b + c) * n * n + i
# ```

# %% [markdown]
# ### Problem 1.4 (8 points)
# This function has a variable inner loop bound. Determine T(n):
#
# ```python
# def diagonal_sum(n):
#     total = 0                  # a step
#     for i in range(n):         # n steps
#         for j in range(i + 1): # let x = i+1, x steps
#             total += i + j     # b step
#     return total               # d step
# ```
#
# **Your answer:**
# ```
# Line by line analysis:
# 6 -> a step
# 7 -> n steps
# 8 -> x steps, because the inner loop bound j runs i+1 step for example.
# diagonal_sum(2) gives:
# i -> 0
# j -> 0
# i -> 1
# j -> 0
# j -> 1
#
# 9 -> b step
# 10 -> d step
#
# Note: The inner loop runs different numbers of times...
#
# T(n) = a + b * x * n + d
# ```

# %% [markdown]
# ### Problem 1.5 (7 points)
# Analyze this function with multiple sequential loops:
#
# ```python
# def multi_pass(L):    # n = len(L)
#     # First pass
#     sum1 = 0                   # a step
#     for x in L:                # n steps
#         sum1 += x              # b step
#
#     # Second pass
#     sum2 = 0                   # c step
#     for y in L:                # n steps
#         sum2 += y * y          # d step
#
#     # Third pass
#     count = 0                  # e step
#     for z in L:                # n steps
#         if z > 0:              # f step
#             count += 1         # i step
#
#     return sum1 + sum2 - count # h step
# ```
#
# **Your answer:**
# ```
# Line by line analysis:
# 7 -> a step
# 8 -> n steps
# 9 -> b step
# 12 -> c step
# 13 -> n step
# 14 -> d step
# 17 -> e step
# 18 -> n steps
# 19 -> f step
# 20 -> i step
# 22 -> h step
#
#
# T(n) = a + b*n + d*n + c + e + (i+f)*n + h
# ```

# %% [markdown]
# ### Problem 1.6 (7 points)
# Analyze this function with nested loops where the inner loop has a constant bound:
#
# ```python
# def fixed_window(L):    # n = len(L)
#     result = []                         # a step
#
#     for i in range(len(L)):             # n steps
#         window_sum = 0                  # b step
#         for j in range(3):              # Always exactly 3 iterations. let x = 3, x steps
#             if i + j < len(L):          # k step
#                 window_sum += L[i + j]  # c step
#         result.append(window_sum)       # d step
#
#     return result                       # i step
# ```
#
# **Your answer:**
# ```
# Line by line analysis:
# 6 -> a step
# 8 -> n steps
# 9 -> b step
# 10 -> x steps
# 11 ->  step
# 12 -> c step
# 13 -> d step
# 15 -> i step
#
#
#
# T(n) = a + (b + c*k*x + d) * n + i
# ```

# %% [markdown]
# ---
# ## Part 2: Big-O Analysis (30 points)
#
# For each T(n) equation, prove the Big-O bound by finding an appropriate constant c.

# %% [markdown]
# ### Problem 2.1 (5 points)
# Show that $T(n) = 4n + 15 \in O(n)$
#
# **Your proof:**
# ```
# We need to show that T(n) ≤ c·n for some constant c and n > n₀.
#
# T(n) = 4n + 15 <= 4n + 15n, for all n >= 1.
#
# Therefore, 4n + 15 <= 19n  with c = _19__, we have shown that T(n) ∈ O(n).
# ```

# %% [markdown]
# ### Problem 2.2 (5 points)
# Show that $T(n) = 2n^2 + 10n + 8 \in O(n^2)$
#
# **Your proof:**
# ```
# We need to show that T(n) ≤ c·n² for some constant c and n > n₀.
#
# T(n) = 2n^2 + 10n + 8 <= 2n^2 + 10n^2 + 8n^2, for all n >= 1.
#
# Therefore, 2n^2 + 10n + 8 <= 20n^2 with c = 20___, we have shown that T(n) ∈ O(n²).
# ```

# %% [markdown]
# ### Problem 2.3 (6 points)
# Show that $T(n) = n^3 + 5n^2 + 3n + 1 \in O(n^3)$
#
# **Your proof:**
# ```
# We need to show that T(n) ≤ c·n³ for some constant c and n > n₀.
#
# T(n) = n^3 + 5n^2 + 3n + 1 <= n^3 + 5n^3 + 3n^3 + n^3, for all n >= 1.
#
# Therefore, n^3 + 5n^2 + 3n + 1 <= 10n^3 with c = 10___, we have shown that T(n) ∈ O(n³).
# ```

# %% [markdown]
# ### Problem 2.4 (7 points)
# Given that a function has the running time equation $T(n) = 3n^2 + 2n + 5$:
#
# a) Prove that $T(n) \in O(n^2)$
#
# b) Prove that $T(n) \in \Omega(n^2)$
#
# c) What can you conclude about $\Theta$?
#
# **Your answer:**
# ```
# a) Upper bound proof:
#
# T(n) = 3n^2 + 2n + 5 <= 3n^2 + 2n^2 + 5n^2, for all n >= 1.
#
# Therefore, 3n^2 + 2n + 5 <= 10n^2, with c = 10, we have show that T(n) is in O(n^2).
#
# b) Lower bound proof:
#
# T(n) = 3n^2 + 2n + 5 >= 3n^2, for all n > 1.
#
# Therefore, 3n^2 + 2n + 5 >= 3n^2, with c = 3, we have shown that T(n) is in Omega(n^2).
# c) Conclusion about Θ:
# 3n^2 <= T(n) <= 10n^2. And T(n) is in Θ(n^2).
#
# ```

# %% [markdown]
# ### Problem 2.5 (7 points)
# You are given that a function's running time satisfies: $n^2 \le T(n) \le 2n^3$
#
# What can you determine about:
# - $T(n) \in O(?)$
# - $T(n) \in \Omega(?)$
# - Can you determine $T(n) \in \Theta(?)$? Why or why not?
#
# **Your answer:**
# ```
# From the inequality n² ≤ T(n) ≤ 2n³:
#
# Upper bound:
#
#
# Lower bound:
#
#
# Tight bound discussion:
#
# ```

# %% [markdown]
# ---
# ## Part 3: Code Complexity Analysis (30 points)
#
# For each code snippet, determine the time complexity and explain your reasoning.

# %% [markdown]
# ### Problem 3.1 (5 points)
# Determine the time complexity:
#
# ```python
# def mystery1(n):
#     count = 0
#     i = n
#     while i > 0:
#         count += 1
#         i = i // 2
#     return count
# ```
#
# **Your answer:**
# ```
# Analysis:
#
#
# Time complexity: O(___)
# Explanation:
# ```

# %% [markdown]
# ### Problem 3.2 (5 points)
# Determine the time complexity:
#
# ```python
# def mystery2(L):    # n = len(L)
#     for i in range(len(L)):
#         for j in range(100):
#             print(L[i], j)
# ```
#
# **Your answer:**
# ```
# Analysis:
#
#
# Time complexity: O(___)
# Explanation:
# ```

# %% [markdown]
# ### Problem 3.3 (6 points)
# Determine the time complexity:
#
# ```python
# def mystery3(L):    # n = len(L)
#     result = 0
#
#     # Phase 1
#     for i in range(len(L)):
#         result += L[i]
#
#     # Phase 2
#     for i in range(len(L)):
#         for j in range(len(L)):
#             result += L[i] * L[j]
#
#     return result
# ```
#
# **Your answer:**
# ```
# Analysis:
# Phase 1:
#
# Phase 2:
#
# Overall time complexity: O(___)
# Explanation:
# ```

# %% [markdown]
# ### Problem 3.4 (7 points)
# Determine the best-case and worst-case time complexity:
#
# ```python
# def find_and_sum(L, target):    # n = len(L)
#     for i in range(len(L)):
#         if L[i] == target:
#             # Found target, now sum everything after it
#             total = 0
#             for j in range(i, len(L)):
#                 total += L[j]
#             return total
#     return 0
# ```
#
# **Your answer:**
# ```
# Best-case analysis:
# Scenario:
# Time complexity: O(___)
#
# Worst-case analysis:
# Scenario:
# Time complexity: O(___)
#
# Explanation:
# ```

# %% [markdown]
# ### Problem 3.5 (7 points)
# Analyze this more complex function:
#
# ```python
# def complex_analysis(L):    # n = len(L)
#     result = []
#
#     for i in range(len(L)):
#         temp_sum = 0
#
#         # Inner loop 1: depends on i
#         for j in range(i):
#             temp_sum += L[j]
#
#         # Inner loop 2: constant iterations
#         for k in range(10):
#             temp_sum *= 2
#
#         result.append(temp_sum)
#
#     return result
# ```
#
# **Your answer:**
# ```
# Detailed analysis:
#
# Outer loop:
#
# Inner loop 1:
#
# Inner loop 2:
#
# Total time complexity: O(___)
#
# Explanation:
# ```
